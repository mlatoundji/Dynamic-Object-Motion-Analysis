# %% [markdown]
# # Build Unified Dataset (Pose + Optical Flow)\n
# \n
# Ce notebook illustre un **smoke test** du pipeline `doma-build-dataset`.\n
# \n
# Pré-requis:\n
# - Python + uv\n
# - (optionnel) `yt-dlp` + `ffmpeg` dans le PATH pour MS-ASL / WLASL\n

# %% [markdown]
# ## Installation\n
# \n
# Depuis la racine du repo:

# %%
# !uv sync --extra dataset --extra hand

# %% [markdown]
# ## Build (subset)\n
# \n
# Adapte `--only` selon les datasets que tu as placés dans `data/raw/`.

# %%
# !uv run doma-build-dataset --config config/datasets.yaml --only ipn_hand,jester --subset 10

# %% [markdown]
# ## MS-ASL / WLASL (download)\n
# \n
# Nécessite `yt-dlp` + `ffmpeg`:

# %%
# !uv run doma-build-dataset --config config/datasets.yaml --only ms_asl,wlasl --download --subset 10
